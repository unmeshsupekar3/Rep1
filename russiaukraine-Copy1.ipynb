# %% [markdown]
# # Russia Ukraine War Analysis & Visualization

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Loading Dataset

# %%
filepath=r"C:\Users\unmes\Downloads\archive\russia_losses_equipment.csv"
df1= pd.read_csv(filepath)
df1
# Out:
#            date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 0    2022-02-25    2        10           7    80   516               49    4
# 1    2022-02-26    3        27          26   146   706               49    4
# 2    2022-02-27    4        27          26   150   706               50    4
# 3    2022-02-28    5        29          29   150   816               74   21
# 4    2022-03-01    6        29          29   198   846               77   24
# ..          ...  ...       ...         ...   ...   ...              ...  ...
# 240  2022-10-23  242       270         245  2584  5284             1667  374
# 241  2022-10-24  243       270         245  2590  5295             1673  375
# 242  2022-10-25  244       271         248  2611  5321             1674  377
# 243  2022-10-26  245       271         248  2628  5351             1686  379
# 244  2022-10-27  246       271         249  2631  5364             1690  379
#
# ...

# %%
df=df1

# %%
df.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 1  2022-02-26    3        27          26   146  706               49    4
# 2  2022-02-27    4        27          26   150  706               50    4
# 3  2022-02-28    5        29          29   150  816               74   21
# 4  2022-03-01    6        29          29   198  846               77   24
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0          100.0       60.0      0           2                      0
# 1          130.0       60.0      2           2                      0
# 2          130.0       60.0      2           2                      0
# 3          291.0       60.0      3           2                      5
# 4          305.0       60.0      3           2                      7
#
#    special equipment  mobile SRBM system greatest losses direction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       245 non-null    object
#  1   day                        245 non-null    int64
#  2   aircraft                   245 non-null    int64
#  3   helicopter                 245 non-null    int64
#  4   tank                       245 non-null    int64
#  5   APC                        245 non-null    int64
#  6   field artillery            245 non-null    int64
#  7   MRL                        245 non-null    int64
#  8   military auto              65 non-null     float64
#  9   fuel tank                  65 non-null     float64
#  10  drone                      245 non-null    int64
#  11  naval ship                 245 non-null    int64
#  12  anti-aircraft warfare      245 non-null    int64
# ...

# %%
df.describe()
# Out:
#               day    aircraft  helicopter         tank          APC  \
# count  245.000000  245.000000  245.000000   245.000000   245.000000
# mean   124.000000  198.951020  173.832653  1475.171429  3391.938776
# std     70.869599   60.575431   47.313141   672.046290  1263.448605
# min      2.000000   10.000000    7.000000    80.000000   516.000000
# 25%     63.000000  185.000000  155.000000   939.000000  2342.000000
# 50%    124.000000  217.000000  184.000000  1552.000000  3687.000000
# 75%    185.000000  234.000000  202.000000  1939.000000  4254.000000
# max    246.000000  271.000000  249.000000  2631.000000  5364.000000
#
#        field artillery         MRL  military auto  fuel tank        drone  \
# count       245.000000  245.000000      65.000000  65.000000   245.000000
# mean        791.518367  218.951020    1047.507692  69.323077   576.661224
# std         431.514067   92.996946     466.162060   7.545917   370.756675
# ...

# %%
df.shape
# Out:
# (245, 18)

# %% [markdown]
# ### Combining columns

# %%
df.loc[:64, 'vehicles and fuel tanks'] = df.loc[:64, 'fuel tank'] + df.loc[:64, 'military auto']
df.loc[:64, 'cruise missiles'] = df.loc[:64, 'mobile SRBM system']
df.drop(columns=['mobile SRBM system', 'military auto', 'fuel tank'],inplace=True)
df
# Out:
#            date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 0    2022-02-25    2        10           7    80   516               49    4
# 1    2022-02-26    3        27          26   146   706               49    4
# 2    2022-02-27    4        27          26   150   706               50    4
# 3    2022-02-28    5        29          29   150   816               74   21
# 4    2022-03-01    6        29          29   198   846               77   24
# ..          ...  ...       ...         ...   ...   ...              ...  ...
# 240  2022-10-23  242       270         245  2584  5284             1667  374
# 241  2022-10-24  243       270         245  2590  5295             1673  375
# 242  2022-10-25  244       271         248  2611  5321             1674  377
# 243  2022-10-26  245       271         248  2628  5351             1686  379
# 244  2022-10-27  246       271         249  2631  5364             1690  379
#
# ...

# %%
df.tail()
# Out:
#            date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 240  2022-10-23  242       270         245  2584  5284             1667  374
# 241  2022-10-24  243       270         245  2590  5295             1673  375
# 242  2022-10-25  244       271         248  2611  5321             1674  377
# 243  2022-10-26  245       271         248  2628  5351             1686  379
# 244  2022-10-27  246       271         249  2631  5364             1690  379
#
#      drone  naval ship  anti-aircraft warfare  special equipment  \
# 240   1361          16                    189              148.0
# 241   1370          16                    189              149.0
# 242   1372          16                    190              149.0
# 243   1379          16                    192              149.0
# 244   1398          16                    192              150.0
#
#     greatest losses direction  vehicles and fuel tanks  cruise missiles
# ...

# %%
df.describe()
# Out:
#               day    aircraft  helicopter         tank          APC  \
# count  245.000000  245.000000  245.000000   245.000000   245.000000
# mean   124.000000  198.951020  173.832653  1475.171429  3391.938776
# std     70.869599   60.575431   47.313141   672.046290  1263.448605
# min      2.000000   10.000000    7.000000    80.000000   516.000000
# 25%     63.000000  185.000000  155.000000   939.000000  2342.000000
# 50%    124.000000  217.000000  184.000000  1552.000000  3687.000000
# 75%    185.000000  234.000000  202.000000  1939.000000  4254.000000
# max    246.000000  271.000000  249.000000  2631.000000  5364.000000
#
#        field artillery         MRL        drone  naval ship  \
# count       245.000000  245.000000   245.000000  245.000000
# mean        791.518367  218.951020   576.661224   11.951020
# std         431.514067   92.996946   370.756675    4.313253
# min          49.000000    4.000000     0.000000    2.000000
# ...

# %%
plt.boxplot(df.APC)
plt.show()

# %%
plt.scatter(df.helicopter,df.aircraft)
plt.show()

# %%
a=df.corr()
a
# Out:
#                               day  aircraft  helicopter      tank       APC  \
# day                      1.000000  0.890928    0.919575  0.992481  0.982573
# aircraft                 0.890928  1.000000    0.979921  0.930987  0.946880
# helicopter               0.919575  0.979921    1.000000  0.949543  0.957740
# tank                     0.992481  0.930987    0.949543  1.000000  0.996099
# APC                      0.982573  0.946880    0.957740  0.996099  1.000000
# field artillery          0.990299  0.882566    0.920978  0.987663  0.972684
# MRL                      0.980645  0.946165    0.960590  0.995932  0.996875
# drone                    0.985260  0.891845    0.915482  0.989346  0.983521
# naval ship               0.878280  0.951872    0.919349  0.914060  0.941272
# anti-aircraft warfare    0.987848  0.916284    0.947041  0.989548  0.978094
# special equipment        0.988443  0.897347    0.970859  0.979606  0.959758
# ...

# %% [markdown]
# ### Getting stuff cleaned

# %%
df2=df.drop(columns=["date","greatest losses direction"])
df2
# Out:
#      day  aircraft  helicopter  tank   APC  field artillery  MRL  drone  \
# 0      2        10           7    80   516               49    4      0
# 1      3        27          26   146   706               49    4      2
# 2      4        27          26   150   706               50    4      2
# 3      5        29          29   150   816               74   21      3
# 4      6        29          29   198   846               77   24      3
# ..   ...       ...         ...   ...   ...              ...  ...    ...
# 240  242       270         245  2584  5284             1667  374   1361
# 241  243       270         245  2590  5295             1673  375   1370
# 242  244       271         248  2611  5321             1674  377   1372
# 243  245       271         248  2628  5351             1686  379   1379
# 244  246       271         249  2631  5364             1690  379   1398
#
#      naval ship  anti-aircraft warfare  special equipment  \
# ...

# %%
sns.heatmap(df2.corr(),annot=True) # To find correlation
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Importing another Dataset

# %%
filepath2=r"C:\Users\unmes\Downloads\archive\russia_losses_personnel.csv"
df3= pd.read_csv(filepath2)
df3
# Out:
#            date  day  personnel personnel*    POW
# 0    2022-02-25    2       2800      about    0.0
# 1    2022-02-26    3       4300      about    0.0
# 2    2022-02-27    4       4500      about    0.0
# 3    2022-02-28    5       5300      about    0.0
# 4    2022-03-01    6       5710      about  200.0
# ..          ...  ...        ...        ...    ...
# 240  2022-10-23  242      67470      about    NaN
# 241  2022-10-24  243      67940      about    NaN
# 242  2022-10-25  244      68420      about    NaN
# 243  2022-10-26  245      68900      about    NaN
# 244  2022-10-27  246      69220      about    NaN
#
# [245 rows x 5 columns]

# %% [markdown]
# ### Combining both the datasets

# %%
df4=df3.merge(df2)    
df4
# Out:
#            date  day  personnel personnel*    POW  aircraft  helicopter  tank  \
# 0    2022-02-25    2       2800      about    0.0        10           7    80
# 1    2022-02-26    3       4300      about    0.0        27          26   146
# 2    2022-02-27    4       4500      about    0.0        27          26   150
# 3    2022-02-28    5       5300      about    0.0        29          29   150
# 4    2022-03-01    6       5710      about  200.0        29          29   198
# ..          ...  ...        ...        ...    ...       ...         ...   ...
# 240  2022-10-23  242      67470      about    NaN       270         245  2584
# 241  2022-10-24  243      67940      about    NaN       270         245  2590
# 242  2022-10-25  244      68420      about    NaN       271         248  2611
# 243  2022-10-26  245      68900      about    NaN       271         248  2628
# 244  2022-10-27  246      69220      about    NaN       271         249  2631
#
# ...

# %%
df4.head()
# Out:
#          date  day  personnel personnel*    POW  aircraft  helicopter  tank  \
# 0  2022-02-25    2       2800      about    0.0        10           7    80
# 1  2022-02-26    3       4300      about    0.0        27          26   146
# 2  2022-02-27    4       4500      about    0.0        27          26   150
# 3  2022-02-28    5       5300      about    0.0        29          29   150
# 4  2022-03-01    6       5710      about  200.0        29          29   198
#
#    APC  field artillery  MRL  drone  naval ship  anti-aircraft warfare  \
# 0  516               49    4      0           2                      0
# 1  706               49    4      2           2                      0
# 2  706               50    4      2           2                      0
# 3  816               74   21      3           2                      5
# 4  846               77   24      3           2                      7
#
#    special equipment  vehicles and fuel tanks  cruise missiles
# ...

# %%
df4.tail()
# Out:
#            date  day  personnel personnel*  POW  aircraft  helicopter  tank  \
# 240  2022-10-23  242      67470      about  NaN       270         245  2584
# 241  2022-10-24  243      67940      about  NaN       270         245  2590
# 242  2022-10-25  244      68420      about  NaN       271         248  2611
# 243  2022-10-26  245      68900      about  NaN       271         248  2628
# 244  2022-10-27  246      69220      about  NaN       271         249  2631
#
#       APC  field artillery  MRL  drone  naval ship  anti-aircraft warfare  \
# 240  5284             1667  374   1361          16                    189
# 241  5295             1673  375   1370          16                    189
# 242  5321             1674  377   1372          16                    190
# 243  5351             1686  379   1379          16                    192
# 244  5364             1690  379   1398          16                    192
#
# ...

# %%
df4.isna().sum()
# Out:
# date                         0
# day                          0
# personnel                    0
# personnel*                   0
# POW                        183
# aircraft                     0
# helicopter                   0
# tank                         0
# APC                          0
# field artillery              0
# MRL                          0
# drone                        0
# naval ship                   0
# anti-aircraft warfare        0
# special equipment           19
# vehicles and fuel tanks      0
# cruise missiles             29
# dtype: int64

# %%
df4.isnull().sum()
# Out:
# date                         0
# day                          0
# personnel                    0
# personnel*                   0
# POW                        183
# aircraft                     0
# helicopter                   0
# tank                         0
# APC                          0
# field artillery              0
# MRL                          0
# drone                        0
# naval ship                   0
# anti-aircraft warfare        0
# special equipment           19
# vehicles and fuel tanks      0
# cruise missiles             29
# dtype: int64

# %% [markdown]
# ###   Exporting into CSV

# %%
df4.to_csv(r'C:\Users\unmes\Downloads\archive\sheet1.csv')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245 entries, 0 to 244
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     245 non-null    object
#  1   day                      245 non-null    int64
#  2   personnel                245 non-null    int64
#  3   personnel*               245 non-null    object
#  4   POW                      62 non-null     float64
#  5   aircraft                 245 non-null    int64
#  6   helicopter               245 non-null    int64
#  7   tank                     245 non-null    int64
#  8   APC                      245 non-null    int64
#  9   field artillery          245 non-null    int64
#  10  MRL                      245 non-null    int64
#  11  drone                    245 non-null    int64
#  12  naval ship               245 non-null    int64
#  13  anti-aircraft warfare    245 non-null    int64
# ...

# %%
filepath3=r"C:\Users\unmes\Downloads\archive\sheet12.csv"
diff_df= pd.read_csv(filepath3)
diff_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 245 non-null    int64
#  1   date                       245 non-null    object
#  2   day                        245 non-null    int64
#  3   personnel                  245 non-null    int64
#  4   D-personnel                245 non-null    int64
#  5   personnel*                 245 non-null    object
#  6   POW                        62 non-null     float64
#  7   D-POW                      245 non-null    int64
#  8   aircraft                   245 non-null    int64
#  9   D-aircraft                 245 non-null    int64
#  10  helicopter                 245 non-null    int64
#  11  D-helicopter               245 non-null    int64
#  12  tank                       245 non-null    int64
# ...

# %%
diff_df1=diff_df
diff_df1
# Out:
#      Unnamed: 0        date  day  personnel  D-personnel personnel*    POW  \
# 0             0  25-02-2022    2       2800         2800      about    0.0
# 1             1  26-02-2022    3       4300         1500      about    0.0
# 2             2  27-02-2022    4       4500          200      about    0.0
# 3             3  28-02-2022    5       5300          800      about    0.0
# 4             4  01-03-2022    6       5710          410      about  200.0
# ..          ...         ...  ...        ...          ...        ...    ...
# 240         240  23-10-2022  242      67470          400      about    NaN
# 241         241  24-10-2022  243      67940          470      about    NaN
# 242         242  25-10-2022  244      68420          480      about    NaN
# 243         243  26-10-2022  245      68900          480      about    NaN
# 244         244  27-10-2022  246      69220          320      about    NaN
#
#      D-POW  aircraft  D-aircraft  ...  naval ship  D-naval ship  \
# ...

# %%
diff_df2=diff_df1.drop(columns=["Unnamed: 0","personnel","personnel*","POW","aircraft","helicopter","tank","APC","field artillery","MRL","drone","naval ship","anti-aircraft warfare","special equipment","vehicles and fuel tanks","cruise missiles"])
diff_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       245 non-null    object
#  1   day                        245 non-null    int64
#  2   D-personnel                245 non-null    int64
#  3   D-POW                      245 non-null    int64
#  4   D-aircraft                 245 non-null    int64
#  5   D-helicopter               245 non-null    int64
#  6   D-tank                     245 non-null    int64
#  7   D-APC                      245 non-null    int64
#  8   D-field artillery          245 non-null    int64
#  9   D-MRL                      245 non-null    int64
#  10  D-drone                    245 non-null    int64
#  11  D-naval ship               245 non-null    int64
#  12  D-anti-aircraft warfare    245 non-null    int64
# ...

# %%
diff_df2.shape
# Out:
# (245, 16)

# %%
diff_df2=diff_df2.fillna(0)
diff_df2.isna().sum()
# Out:
# date                         0
# day                          0
# D-personnel                  0
# D-POW                        0
# D-aircraft                   0
# D-helicopter                 0
# D-tank                       0
# D-APC                        0
# D-field artillery            0
# D-MRL                        0
# D-drone                      0
# D-naval ship                 0
# D-anti-aircraft warfare      0
# D-special equipment          0
# D-vehicles and fuel tanks    0
# D-cruise missiles            0
# dtype: int64

# %%
diff_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       245 non-null    object
#  1   day                        245 non-null    int64
#  2   D-personnel                245 non-null    int64
#  3   D-POW                      245 non-null    int64
#  4   D-aircraft                 245 non-null    int64
#  5   D-helicopter               245 non-null    int64
#  6   D-tank                     245 non-null    int64
#  7   D-APC                      245 non-null    int64
#  8   D-field artillery          245 non-null    int64
#  9   D-MRL                      245 non-null    int64
#  10  D-drone                    245 non-null    int64
#  11  D-naval ship               245 non-null    int64
#  12  D-anti-aircraft warfare    245 non-null    int64
# ...

# %%
diff_df2=diff_df2.astype({"D-special equipment":"int64","D-cruise missiles":"int64"})
diff_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       245 non-null    object
#  1   day                        245 non-null    int64
#  2   D-personnel                245 non-null    int64
#  3   D-POW                      245 non-null    int64
#  4   D-aircraft                 245 non-null    int64
#  5   D-helicopter               245 non-null    int64
#  6   D-tank                     245 non-null    int64
#  7   D-APC                      245 non-null    int64
#  8   D-field artillery          245 non-null    int64
#  9   D-MRL                      245 non-null    int64
#  10  D-drone                    245 non-null    int64
#  11  D-naval ship               245 non-null    int64
#  12  D-anti-aircraft warfare    245 non-null    int64
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(diff_df2.corr(),annot=True) # To find correlation
# Out:
# <AxesSubplot:>

# %%
diff_df2.corr()
# Out:
#                                 day  D-personnel     D-POW  D-aircraft  \
# day                        1.000000    -0.048198 -0.219830   -0.410265
# D-personnel               -0.048198     1.000000  0.016724    0.264085
# D-POW                     -0.219830     0.016724  1.000000    0.035699
# D-aircraft                -0.410265     0.264085  0.035699    1.000000
# D-helicopter              -0.295857     0.302612  0.090663    0.444290
# D-tank                    -0.232695     0.440693  0.251735    0.455232
# D-APC                     -0.271241     0.611810  0.030977    0.441766
# D-field artillery          0.114521     0.315237 -0.074631    0.055895
# D-MRL                     -0.167560     0.147318  0.012645    0.021615
# D-drone                    0.288631     0.015466 -0.114883   -0.135201
# D-naval ship              -0.189440     0.219600 -0.004346    0.156464
# D-anti-aircraft warfare   -0.118521     0.127721  0.099394    0.078788
# ...

# %%
from scipy.stats import pearsonr
list1 = diff_df2['D-personnel']
list2 = diff_df2['D-APC']    #'D-aircraft','D-helicopter','D-tank',
 
# Apply the pearsonr()
corr, _ = pearsonr(list1, list2)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.612

# %%
diff_df2.to_csv(r'C:\Users\unmes\Downloads\archive\sheet3.csv')

# %%
diff_df2.plot(x="day", y=["D-personnel"], kind="line", figsize=(9, 8))
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# pip install torch pytorch-lightning pytorch_forecasting

# %%
# Out:
# The syntax of the command is incorrect.

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
# !kaggle datasets download -d piterfm/2022-ukraine-russian-war
# Out:
# 2022-ukraine-russian-war.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Out:
# None
